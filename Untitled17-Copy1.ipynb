L_COUNT      RATIO  CONVICTED  VAR_1  VAR_2    VAR_3  \
# 0   119.166667      19.0        NaN          0      0      1  2.00950
# 1   174.786162      24.0  40.067527          0      0      1  1.27240
# 2   242.736126      42.0  39.231892          1      0      2  1.47250
# 3   204.900000      40.0        NaN          0      1      2  1.57010
# 4    84.111988      15.0  29.865634          0      0      1  1.50130
# 5   289.581891      20.0  28.285563          0      0      0  1.51770
# 6   176.339376      24.0  38.266594          0      0      1  2.43220
# 7   333.409840      28.0  30.778638          0      0      0  0.82074
# 8   182.172065      18.0  33.210397          0      0      0  2.23040
# 9   194.766667      20.0        NaN          0      0      0  1.24350
# 10  205.484583      19.0  21.865494          0      0      0  2.05320
# 11  186.005435      22.0  38.906039          0      0      1  1.70780
# 12   42.807205       3.0  26.966698          0      0      1  1.04730
# 13   74.756690      15.0  41.833085          0      0      0  1.35240
# 14  218.944828      13.0  41.145649          0      0      0  1.29390
# 15  213.783283      16.0  31.130133          0      0      0  2.31800
# 16   80.677885      20.0  33.783303          0      0      1  2.52490
# 17  116.002195      17.0  32.261086          1      0      0  1.08040
# 18  152.715066      21.0  34.873596          0      0      1  2.73610
# 19  165.330898      34.0  32.385149          0      0      0  0.26382
# 20  280.198021      37.0  42.997979          1      0      1  1.14930
# 21  172.212815      21.0  35.168703          0      0      0  1.61750
# 22  183.180257      29.0  37.083413          0      2      3  1.01980
# 23  158.246550      11.0  33.566312          0      0      0  0.46997
# 24  129.833333      26.0        NaN          0      0      0  0.94674
# 25  271.260197      18.0  39.964573          1      0      0  1.86190
# 26   57.309765      21.0  23.531188          0      0      8  1.73400
# 27  135.504348       9.0  29.393997          1      0      0  1.35250
# 28  280.007081      17.0  36.082975          0      1      1  2.48260
# 29  208.288933      20.0  29.228895          0      0      0  1.10520
# 30  137.900000      35.0        NaN          0      0      0  1.15840
# 31  155.484814      35.0  41.129153          0      0      2  0.70712
# 32  308.636664      10.0  30.372484          1      0      0  2.74330
# 33   91.300000      29.0        NaN          1      6      6  1.39550
# 34  211.189005      49.0  41.346627          0      0      3  2.31030
# 35   56.873860       4.0  38.385091          0      0      0  2.45640
# 36  205.025593      38.0        NaN          0      3      1  0.66074
# 37  115.843030      14.0  26.335111          0      0      1  2.64290
# 38  297.211490      18.0  30.311365          0      0      1  2.58950
# 39  110.566667      35.0        NaN          1      0      5  1.89020
#
#     DEFAULTER
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# 5           0
# 6           0
# 7           0
# 8           0
# 9           0
# 10          0
# 11          0
# 12          1
# 13          0
# 14          0
# 15          0
# 16          0
# 17          0
# 18          0
# 19          0
# 20          0
# 21          0
# 22          0
# 23          0
# 24          0
# 25          0
# 26          0
# 27          0
# 28          0
# 29          0
# 30          0
# 31          0
# 32          0
# 33          1
# 34          0
# 35          0
# 36          1
# 37          0
# 38          0
# 39          1

# %%
print(df['DEFAULTER'].value_counts())
# Out:
# 0    2869
# 1     707
# Name: DEFAULTER, dtype: int64

# %%
X = df.drop('DEFAULTER', 1)
Y = df.DEFAULTER

# %%
X.head()
# Out:
#    LOAN_ID  AMOUNT  DUE_MORTGAGE     VALUE  REASON  OCC  TJOB  DCL  \
# 0  3682648   15100       71168.0   97480.0     1.0  0.0   9.0  0.0
# 1  3682649   21100       81747.0  109840.0     1.0  0.0   NaN  0.0
# 2  3682650   15900       94262.0  128414.0     1.0  3.0   4.0  NaN
# 3  3682651   12900      110899.0  124480.0     1.0  2.0   7.0  0.0
# 4  3682652   24600           NaN   35523.0     0.0  0.0  21.0  0.0
#
#           CLT  CL_COUNT      RATIO  CONVICTED  VAR_1  VAR_2   VAR_3
# 0  119.166667      19.0        NaN          0      0      1  2.0095
# 1  174.786162      24.0  40.067527          0      0      1  1.2724
# 2  242.736126      42.0  39.231892          1      0      2  1.4725
# 3  204.900000      40.0        NaN          0      1      2  1.5701
# 4   84.111988      15.0  29.865634          0      0      1  1.5013

# %%
X.isnull().sum().sort_values(ascending=False).head()
# Out:
# RATIO           751
# DCL             337
# DUE_MORTGAGE    318
# TJOB            309
# CLT             187
# dtype: int64

# %%
from sklearn.preprocessing import Imputer
imp = Imputer(missing_
    floor = q1 - 1.5*iqr
    ceiling = q3 + 1.5*iqr
    outlier_indices = list(x.index[(x < floor)|(x > ceiling)])
    outlier_values = list(x[outlier_indices])
    
    return outlier_indices, outlier_values

# %%
turkey_indices, turkey_values = find_outliers_turkey(X['AMOUNT'])
print(np.sort(turkey_values))
# Out:
# [41300. 41300. 41300. 41400. 41500. 41500. 41600. 41700. 41700. 41700.
#  41800. 41900. 42100. 42200. 42300. 42400. 42400. 42500. 42600. 42600.
#  42700. 42700. 42900. 42900. 42900. 42900. 43000. 43000. 43000. 43300.
#  43300. 43400. 43400. 43400. 43400. 43800. 43900. 44000. 44100. 44200.
#  44500. 44500. 45000. 45100. 45100. 45200. 45800. 45800. 46000. 46300.
#  46800. 47100. 47100. 47100. 47100. 47200. 47600. 47600. 47700. 47700.
#  47800. 48000. 48100. 48300. 48500. 49000. 49000. 49600. 49600. 49900.
#  50100. 50100. 50100. 50100. 50100. 50100. 50100. 50100. 50100. 50200.
#  50200. 50300. 50400. 50500. 50900. 51000. 51000. 51000. 51200. 51400.
#  51600. 51700. 51800. 51900. 52100. 52100. 52300. 52300. 52300. 52500.
#  52800. 52900. 53000. 53100. 53500. 53700. 53700. 53800. 53800. 53900.
#  53900. 54000. 56900. 57100. 59300. 59300. 59800. 59900. 60100. 60100.
#  60600. 61500. 62600. 63000. 63400. 64000. 65200. 65300. 65300. 65900.
#  67500. 68200. 69100. 69800. 70400. 72400. 76600. 77300. 77500. 78500.
#  78800. 79300. 79300. 80400. 81300. 81500. 86100. 87600. 88900. 89000.
#  89900.]

# %%
from sklearn.preprocessing import scale
from statsmodels.nonparametric.kde import KDEUnivariate

def find_outlier_kde(x):
    x_scaled = scale(list(map(float, x)))
    kde = KDEUnivariate(x_scaled)
    kde.fit(bw="scott",  fft = True)
    pred = kde.evaluate(x_scaled)
    
    n = sum(pred < 0.05)
    outlier_ind = np.asarray(pred).argsort()[:n]
    outlier_value = np.asarray(x)[outlier_ind]
    
    return outlier_ind, outlier_value

# %%
kde_indices , kde_values = find_outlier_kde(X['AMOUNT'])

# %%
def plot_histogram(x):
    plt.hist(x, color = 'grey', alpha = 0.5)
    plt.title("Histogram of {var_name}".format(var_name = x.name))
    plt.xlabel("value")
    plt.ylabel("Frequency")
    plt.show()

# %%
plot_histogram(X["AMOUNT"])

# %%
def plot_histogram_dv(x, y):
    plt.hist(list(x[y==0]), alpha=0.5, label='DV=0')
    plt.hist(list(x[y==1]), alpha=0.5, label='DV=1')
    plt.title("Histogram of {var_name} by DV category".format(var_name = x.name))
    plt.xlabel("value")
    plt.ylabel("Frequency")
    plt.legend(loc = 'upper right')
    plt.show()

# %%
plot_histogram_dv(X['DUE_MORTGAGE'], Y)

# %%
#FEATURE ENGINEERING
from itertools import combinations
from sklearn.decomposition import PCA

pca = PCA(n_components=14)
X_pca = pd.DataFrame(pca.fit_transform(X))

# %%
print(X_pca.head(5))
# Out:
#              0             1             2            3          4   \
# 0  -4660.800218  -1063.190044  -3149.284226  1780.721808 -63.969332
# 1  11855.090133  -1594.172578   2107.019688  1785.494893 -12.802396
# 2  33931.158000  -1486.604741  -4319.048352  1763.055176  52.061007
# 3  40455.776094 -17517.052261  -5630.505075  1739.357506  17.850282
# 4 -57151.237669 -31667.383759  13140.105741  1797.106746 -81.876582
#
#           5          6         7         8         9         10        11  \
# 0  -0.274031  -1.305829  0.998612  0.271628  1.640689 -0.408126 -0.125524
# 1   3.541291   3.087721  4.442263  0.117958  1.828062 -0.424511 -0.156254
# 2  18.281078   6.160868 -0.558244  0.258454 -0.715966 -0.810526 -0.203780
# 3  15.268667   0.390664 -3.622411  0.761791  0.251331 -0.596434  0.814524
# 4  -3.381535 -15.335003  0.202977  0.068958  1.090697 -0.461355 -0.090729
#
#          12        13
# 0 -0.374659 -0.239561
# 1  0.345364 -0.185765
# 2  0.141547 -0.192097
# 3  0.075449 -0.180984
# 4  0.089537  0.829221

# %%
#cross-validation

from sklearn.cross_validation import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_pca, Y, train_size=0.70, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score


def find_model_perf(X_train, Y_train, X_test, Y_test):
    model = LogisticRegression()
    model.fit(X_train, Y_train)
    Y_hat = [x[1] for x in model.predict_proba(X_test)]
    auc = roc_auc_score(Y_test, Y_hat)
    
    return auc

# %%
auc_processed = find_model_perf(X_train, Y_train, X_test, Y_test)
print(auc_processed)
# Out:
# 0.79551073445

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %%
def classification_model(model, data, outcome):
  #Fit the model:
  model.fit(data,outcome)
  
  #Make predictions on training set:
  predictions = model.predict(data)
  
  #Print accuracy
  accuracy = metrics.accuracy_score(predictions,outcome)
  print ("Accuracy : %s" % "{0:.3%}".format(accuracy))

  #Perform k-fold cross-validation with 5 folds
  kf = KFold(data.shape[0], n_folds=10)
  error = []
  for train, test in kf:
    # Filter training data
    train_predictors = (data.iloc[train,:])
    
    # The target we're using to train the algorithm.
    train_target = outcome.iloc[train]
    
    # Training the algorithm using the predictors and target.
    model.fit(train_predictors, train_target)
    
    #Record error from each cross-validation run
    error.append(model.score(data.iloc[test,:], outcome.iloc[test]))
 
  print ("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))
  #auc_processed = find_model_perf(train_predictors, Y_train, X_test, Y_test)
  #print(auc_processed)
  #Fit the model again so that it can be refered outside the function:
  model.fit(data, outcome)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
classification_model(model, X_pca, Y)
# Out:
# Accuracy : 81.152%
# Cross-Validation Score : 81.011%

# %%
classification_model(DecisionTreeClassifier(), X_pca, Y)
# Out:
# Accuracy : 100.000%
# Cross-Validation Score : 83.752%

# %%
from sklearn.ensemble import GradientBoostingClassifier
model= GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0)

classification_model(model, X_pca, Y)
# Out:
# Accuracy : 89.094%
# Cross-Validation Score : 86.045%

# %%
model = RandomForestClassifier(n_estimators=100)
classification_model(model, X_pca, Y)
# Out:
# Accuracy : 100.000%
# Cross-Validation Score : 89.541%

# %%
predictor_var=['AMOUNT','DUE_MORTGAGE','VALUE','REASON','OCC','TJOB','DCL','CLT','CL_COUNT','RATIO','CONVICTED','VAR_1','VAR_2','VAR_3']
featimp = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False)
print (featimp)
# Out:
# CONVICTED       0.145447
# VAR_1           0.102329
# CLT             0.094393
# OCC             0.091181
# AMOUNT          0.077876
# TJOB            0.067859
# VALUE           0.065475
# RATIO           0.065081
# CL_COUNT        0.064785
# DUE_MORTGAGE    0.053922
# DCL             0.052421
# VAR_3           0.050020
# VAR_2           0.037636
# REASON          0.031575
# dtype: float64

# %%
model = RandomForestClassifier(n_estimators=25, min_samples_split=25, max_depth=7, max_features=1)
predictor_var = ['CONVICTED','VAR_1 ','CLT','OCC ','AMOUNT']
classification_model(model, X_pca, Y)
# Out:
# Accuracy : 84.200%
# Cross-Validation Score : 81.739%

# %%
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

X1 = X.iloc[0:8]
Y1 = Y.iloc[0:8]
seed = 7
kfold = model_selection.KFold(n_splits=8, random_state=seed)
cart = DecisionTreeClassifier()
num_trees = 100
model = BaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, X1, Y1, cv=kfold)
print(results.mean())
# Out:
# 0.75

# %%
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier

seed = 7
num_trees = 100
max_features = 3
kfold = model_selection.KFold(n_splits=8, random_state=seed)
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
results = model_selection.cross_val_score(model, X1, Y1, cv=kfold)
print(results.mean())
# Out:
# 0.75

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier

seed = 7
num_trees = 30
kfold = model_selection.KFold(n_splits=8, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, X1, Y1, cv=kfold)
print(results.mean())
# Out:
# 0.5

# %%
from sklearn import model_selection
from sklearn.ensemble import GradientBoostingClassifier

seed = 7
num_trees = 100
kfold = model_selection.KFold(n_splits=8, random_state=seed)
model = GradientBoostingClassifier(n_estimators=num_trees, random_state=seed)
results = model_selection.cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.897371364653
